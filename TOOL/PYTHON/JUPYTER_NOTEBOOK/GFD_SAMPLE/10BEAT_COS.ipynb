# %%
import numpy as np
import matplotlib.pyplot as plt

NAME='u1+u2'; TITLE='u1+u2'
#NAME='u1'; TITLE='u1'

LCLR="black"
LSTY="solid"

A1=0.5; T1=1; L1=6.; o1=2.0*np.pi/T1; k1=2.0*np.pi/L1; c1=o1/k1
LCLR1="r"
LSTY1="solid" #dashed"

A2=0.5; T2=1; L2=6.; o2=o1+o1/5.0; k2=k1+k1/5.0; c2=o2/k2
LCLR2="b"
LSTY2="solid" #dashed"

print(str(k1)+" "+str(o1))
print(str(k2)+" "+str(o2))

print(c1); print(c2)

xmin=-5; xmax=60; xint=10
x = np.linspace(xmin, xmax, 300)

plt, ax=plt.subplots(figsize=(6, 3), dpi=300, tight_layout=True)

ax.set_xlim(xmin, xmax)
ax.set_ylim(-2, 2)

t=2

u1=A1*np.cos(k1*x-o1*t)
u2=A2*np.cos(k2*x-o2*t)
u=u1+u2

ax.plot(x,u, color=LCLR, ls=LSTY, label="")

#ax.plot(x,u1, color=LCLR1, ls=LSTY1, label="t="+str(t))
#ax.plot(x,u2, color=LCLR2, ls=LSTY2, label="t="+str(t))

start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, xint))

ax.axhline(0, ls='-', c='b', lw=0.5)
ax.axvline(0, ls='-', c='b', lw=0.5)

ax.tick_params(labelsize=16)

ax.legend(fontsize=0,loc=3)
ax.legend(frameon=False)
ax.set_xlabel('x', fontsize=18)
ax.set_ylabel(NAME, fontsize=18)
ax.set_title("t="+str(t)+" "+TITLE ,fontsize=25)

plt.show()

# https://qiita.com/eriho/items/21302ab7e95a2721b9f8
# matplotlibにはplt.plotをベースしたmatlab準拠の方法と、
# ax.plotをベースとしたオブジェクト指向の方法がある
#
# 最初からax.plot方式に慣れておいた方がいい
#
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 1.0471975511965976 6.283185307179586
# 1.2566370614359172 7.5398223686155035
# 6.0
# 6.0
# <ipython-input-5-0a386db563a3>:56: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

NAME='u'; TITLE='u1 & u2'
#NAME='u1'; TITLE='u1'



LCLR="black"
LSTY="solid"

A1=0.5; T1=1; L1=6.; o1=2.0*np.pi/T1; k1=2.0*np.pi/L1; c1=o1/k1
LCLR1="r"
LSTY1="solid" #dashed"

A2=0.5; T2=1; L2=6.; o2=o1+o1/5.0; k2=k1+k1/5.0; c2=o2/k2
LCLR2="b"
LSTY2="solid" #dashed"

#print(c1); print(c2)

xmin=-5; xmax=60; xint=10
x = np.linspace(xmin, xmax, 300)

plt, ax=plt.subplots(figsize=(6, 3), dpi=300, tight_layout=True)

ax.set_xlim(xmin, xmax)
ax.set_ylim(-2, 2)

t=2
u1=A1*np.cos(k1*x-o1*t)
u2=A2*np.cos(k2*x-o2*t)
u=u1+u2

#u=u1+u2
#ax.plot(x,u, color=LCLR, ls=LSTY, label="")

ax.plot(x,u1, color=LCLR1, ls=LSTY1, label="")
ax.plot(x,u2, color=LCLR2, ls=LSTY2, label="")

start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, xint))

ax.axhline(0, ls='-', c='b', lw=0.5)
ax.axvline(0, ls='-', c='b', lw=0.5)

ax.tick_params(labelsize=16)

ax.legend(fontsize=0,loc=3)
ax.legend(frameon=False)
ax.set_xlabel('x', fontsize=18)
ax.set_ylabel(NAME, fontsize=18)
ax.set_title("t="+str(t)+" "+TITLE ,fontsize=25)

plt.show()

# https://qiita.com/eriho/items/21302ab7e95a2721b9f8
# matplotlibにはplt.plotをベースしたmatlab準拠の方法と、
# ax.plotをベースとしたオブジェクト指向の方法がある
#
# 最初からax.plot方式に慣れておいた方がいい
#
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# <ipython-input-7-a18c18f98555>:55: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

NAME='u1+u2'; TITLE='u1+u2'
#NAME='u1'; TITLE='u1'

LCLR="black"
LSTY="solid"

A1=0.5; T1=1; L1=6.; o1=2.0*np.pi/T1; k1=2.0*np.pi/L1; c1=o1/k1
LCLR1="r"
LSTY1="solid" #dashed"

A2=0.5; T2=1; L2=6.; o2=o1+o1/5.0; k2=k1+k1/5.0; c2=o2/k2
LCLR2="b"
LSTY2="solid" #dashed"

kav=(k1+k2)/2; oav=(o1+o2)/2; dk=k1-k2; do=o1-o2 
LCLR3="r"
LSTY3="solid" #dashed"

print(str(k1)+" "+str(o1))
print(str(k2)+" "+str(o2))

print(c1); print(c2)

xmin=-5; xmax=60; xint=10
x = np.linspace(xmin, xmax, 300)

plt, ax=plt.subplots(figsize=(6, 3), dpi=300, tight_layout=True)

ax.set_xlim(xmin, xmax)
ax.set_ylim(-2, 2)

t=2

u1=A1*np.cos(k1*x-o1*t)
u2=A2*np.cos(k2*x-o2*t)
u=u1+u2
ua=2*A1*np.cos(dk/2*x-do/2*t)

ax.plot(x,u, color=LCLR, ls=LSTY, label="")

ax.plot(x,ua, color=LCLR3, ls=LSTY3, label="")
ax.plot(x,-ua, color=LCLR3, ls=LSTY3, label="")
#ax.plot(x,u1, color=LCLR1, ls=LSTY1, label="t="+str(t))
#ax.plot(x,u2, color=LCLR2, ls=LSTY2, label="t="+str(t))

start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, xint))

ax.axhline(0, ls='-', c='b', lw=0.5)
ax.axvline(0, ls='-', c='b', lw=0.5)

ax.tick_params(labelsize=16)

ax.legend(fontsize=0,loc=3)
ax.legend(frameon=False)
ax.set_xlabel('x', fontsize=18)
ax.set_ylabel(NAME, fontsize=18)
ax.set_title("t="+str(t)+" "+TITLE ,fontsize=25)

plt.show()

# https://qiita.com/eriho/items/21302ab7e95a2721b9f8
# matplotlibにはplt.plotをベースしたmatlab準拠の方法と、
# ax.plotをベースとしたオブジェクト指向の方法がある
#
# 最初からax.plot方式に慣れておいた方がいい
#
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 1.0471975511965976 6.283185307179586
# 1.2566370614359172 7.5398223686155035
# 6.0
# 6.0
# <ipython-input-7-cf0e41044a80>:63: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
