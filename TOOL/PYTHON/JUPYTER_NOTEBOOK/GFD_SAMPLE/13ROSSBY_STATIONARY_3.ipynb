# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

NAME='Z1+Z2'; TITLE='Z1+Z2'

LCLR="black"
LSTY="solid"

LCLR1="r"
LSTY1="solid" #dashed"

LCLR2="b"
LSTY2="solid" #dashed"

LCLR3="purple"
LSTY3="solid" #dashed"

d2r=np.pi/180.
L1=60 # degree
L2=120
#L2=45 # degree
k1=2*np.pi/L1
k2=2*np.pi/L2
c1=0
#c2=30
c2=-30
o1=k1*c1
o2=k2*c2


TITLE='Z1(c1='+str(c1)+' L1='+str(L1)+') Z2(c2='+str(c2)+' L2='+str(L2)+')'

amp=100

plt, ax=plt.subplots(figsize=(6, 3), dpi=300, tight_layout=True)

y=0

xmin=0; xmax=360; xint=60
x = np.linspace(xmin, xmax, 360)


phi0=0*d2r


t=1
#y1=amp*np.cos(k*(x-c*t) + phi0)

y1=amp*np.cos(k1*(x-c1*t) + phi0)

y2=amp*np.cos(k2*(x-c2*t) + phi0 )

y=y1+y2

ye=2*amp*np.cos( (k1*(x-c1*t)-k2*(x-c2*t))/2  )

ax.plot(x,y, color=LCLR, ls=LSTY, label="")

ax.plot(x,y1, color=LCLR1, ls=LSTY1, label="")
ax.plot(x,y2, color=LCLR2, ls=LSTY2, label="")

ax.plot(x, ye, color=LCLR3, ls=LSTY3, label="")
ax.plot(x,-ye, color=LCLR3, ls=LSTY3, label="")


start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(0, 360, xint))
#ax.xaxis.set_ticks(np.arange(start, end, xint))

ax.axhline(0, ls='-', c='b', lw=0.5)
ax.axvline(0, ls='-', c='b', lw=0.5)

ax.set_xlim(xmin, xmax)
ax.set_ylim(-amp*2.5, amp*2.5)

ax.tick_params(labelsize=14)

ax.legend(fontsize=0,loc=3)
ax.legend(frameon=False)
ax.set_xlabel('longitude [deg]', fontsize=14)
ax.set_ylabel(NAME, fontsize=14)
ax.set_title("t="+str(t)+" "+TITLE ,fontsize=16)

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# <ipython-input-34-712655f523ff>:85: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

NAME='Z1 & Z2'

LCLR="black"
LSTY="solid"

A1=0.5; T1=1; L1=6.; o1=2.0*np.pi/T1; k1=2.0*np.pi/L1; c1=o1/k1
LCLR1="r"
LSTY1="solid" #dashed"

A2=0.5; T2=1; L2=6.; o2=o1+o1/5.0; k2=k1+k1/5.0; c2=o2/k2
LCLR2="b"
LSTY2="solid" #dashed"

kav=(k1+k2)/2; oav=(o1+o2)/2; dk=k1-k2; do=o1-o2 
LCLR3="r"
LSTY3="solid" #dashed"

d2r=np.pi/180.
L1=60 # degree
L2=120
#L2=45 # degree
k1=2*np.pi/L1
k2=2*np.pi/L2
c1=0
#c2=30
c2=-30

o1=k1*c1
o2=k2*c2

TITLE='Z1(c1='+str(c1)+' L1='+str(L1)+') Z2(c2='+str(c2)+' L2='+str(L2)+')'

amp=100

plt, ax=plt.subplots(figsize=(6, 3), dpi=300, tight_layout=True)

y=0

xmin=0; xmax=360; xint=60
x = np.linspace(xmin, xmax, 360)


phi0=0*d2r


t=1

#y1=amp*np.cos(k*(x-c*t) + phi0)

y1=amp*np.cos(k1*(x-c1*t) + phi0)

y2=amp*np.cos(k2*(x-c2*t) + phi0 )

y=y1+y2

#ye=2*amp*np.cos(delk*x+delo*t)

#ax.plot(x,y, color=LCLR, ls=LSTY, label="")

ax.plot(x,y1, color=LCLR1, ls=LSTY1, label="")
ax.plot(x,y2, color=LCLR2, ls=LSTY2, label="")


start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(0, 360, xint))
#ax.xaxis.set_ticks(np.arange(start, end, xint))

ax.axhline(0, ls='-', c='b', lw=0.5)
ax.axvline(0, ls='-', c='b', lw=0.5)

ax.set_xlim(xmin, xmax)
ax.set_ylim(-amp*2.5, amp*2.5)

ax.tick_params(labelsize=14)

ax.legend(fontsize=0,loc=3)
ax.legend(frameon=False)
ax.set_xlabel('longitude [deg]', fontsize=14)
ax.set_ylabel(NAME, fontsize=14)
ax.set_title("t="+str(t)+" "+TITLE ,fontsize=16)

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# <ipython-input-33-2b385234c899>:86: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
