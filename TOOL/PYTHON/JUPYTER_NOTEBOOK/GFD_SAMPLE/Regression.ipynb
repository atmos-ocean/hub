# %%
import os

# %%
import pandas as pd

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
os.chdir("C:\\Users\\atmos\\Dropbox\\AM\\TOOL\JUPYTER\\REGRESSION")

# %%
df1 = pd.read_csv("meiv2.data.txt", sep='\s+',index_col=0)

# %%
mei=df1.iloc[:,0]

# %%
mei
# Out:
# year
# 1979    0.47
# 1980    0.35
# 1981   -0.33
# 1982   -0.38
# 1983    2.57
# 1984   -0.50
# 1985   -0.25
# 1986   -0.36
# 1987    0.98
# 1988    0.59
# 1989   -1.09
# 1990    0.12
# 1991    0.16
# 1992    1.70
# 1993    0.83
# 1994    0.02
# 1995    0.77
# 1996   -0.83
# 1997   -0.66
# 1998    2.23
# 1999   -1.26
# 2000   -1.26
# 2001   -0.82
# 2002    0.07
# 2003    0.80
# 2004    0.16
# 2005    0.08
# 2006   -0.68
# 2007    0.62
# 2008   -1.08
# 2009   -1.01
# 2010    0.93
# 2011   -1.83
# 2012   -1.08
# 2013   -0.05
# 2014   -0.51
# 2015    0.23
# 2016    1.94
# 2017   -0.41
# 2018   -0.77
# 2019    0.08
# Name: DJ, dtype: float64

# %%
df1
# Out:
#         DJ    JF    FM    MA    AM    MJ    JJ    JA    AS    SO    ON    ND
# year
# 1979  0.47  0.26 -0.08  0.20  0.27 -0.15 -0.14  0.44  0.38  0.24  0.52  0.65
# 1980  0.35  0.19  0.41  0.59  0.55  0.62  0.62  0.15  0.20  0.09 -0.03 -0.06
# 1981 -0.33 -0.24  0.33  0.41 -0.27 -0.60 -0.51 -0.31 -0.01 -0.10 -0.22 -0.16
# 1982 -0.38 -0.47 -0.28 -0.34 -0.03  0.78  1.79  2.02  1.81  1.93  2.28  2.48
# 1983  2.57  2.74  2.68  2.79  2.89  2.02  0.75 -0.11 -0.41 -0.43 -0.43 -0.43
# 1984 -0.50 -0.52 -0.11  0.09 -0.47 -0.72 -0.31 -0.15 -0.11 -0.15 -0.58 -0.31
# 1985 -0.25 -0.58 -0.60 -0.76 -1.22 -0.57 -0.02 -0.37 -0.44 -0.04  0.00 -0.34
# 1986 -0.36 -0.30 -0.39 -0.52 -0.18  0.12  0.56  1.05  1.31  0.57  0.65  1.06
# 1987  0.98  1.08  1.47  1.66  1.91  2.02  1.92  1.48  1.23  1.13  0.85  0.75
# 1988  0.59  0.31  0.19 -0.01 -0.36 -1.19 -1.77 -1.79 -1.77 -1.54 -1.61 -1.49
# 1989 -1.09 -1.06 -1.20 -1.09 -1.04 -1.02 -1.12 -0.73 -0.61 -0.56 -0.33 -0.02
# ...

# %%
nd=(2019-1978)*12

# %%
print(nd)
# Out:
# 492

# %%
mei = np.resize(df1, [nd])

# %%
mei
# Out:
# array([ 0.47,  0.26, -0.08,  0.2 ,  0.27, -0.15, -0.14,  0.44,  0.38,
#         0.24,  0.52,  0.65,  0.35,  0.19,  0.41,  0.59,  0.55,  0.62,
#         0.62,  0.15,  0.2 ,  0.09, -0.03, -0.06, -0.33, -0.24,  0.33,
#         0.41, -0.27, -0.6 , -0.51, -0.31, -0.01, -0.1 , -0.22, -0.16,
#        -0.38, -0.47, -0.28, -0.34, -0.03,  0.78,  1.79,  2.02,  1.81,
#         1.93,  2.28,  2.48,  2.57,  2.74,  2.68,  2.79,  2.89,  2.02,
#         0.75, -0.11, -0.41, -0.43, -0.43, -0.43, -0.5 , -0.52, -0.11,
#         0.09, -0.47, -0.72, -0.31, -0.15, -0.11, -0.15, -0.58, -0.31,
#        -0.25, -0.58, -0.6 , -0.76, -1.22, -0.57, -0.02, -0.37, -0.44,
#        -0.04,  0.  , -0.34, -0.36, -0.3 , -0.39, -0.52, -0.18,  0.12,
#         0.56,  1.05,  1.31,  0.57,  0.65,  1.06,  0.98,  1.08,  1.47,
#         1.66,  1.91,  2.02,  1.92,  1.48,  1.23,  1.13,  0.85,  0.75,
#         0.59,  0.31,  0.19, -0.01, -0.36, -1.19, -1.77, -1.79, -1.77,
# ...

# %%
print(len(mei))
# Out:
# 492

# %%
time=[0]*nd

# %%
i = 0

while i < nd:
    time[i]=1979+ (i) *(1.0/12.0)
    i += 1

# %%
time
# Out:
# array([1979.        , 1979.08333333, 1979.16666667, 1979.25      ,
#        1979.33333333, 1979.41666667, 1979.5       , 1979.58333333,
#        1979.66666667, 1979.75      , 1979.83333333, 1979.91666667,
#        1980.        , 1980.08333333, 1980.16666667, 1980.25      ,
#        1980.33333333, 1980.41666667, 1980.5       , 1980.58333333,
#        1980.66666667, 1980.75      , 1980.83333333, 1980.91666667,
#        1981.        , 1981.08333333, 1981.16666667, 1981.25      ,
#        1981.33333333, 1981.41666667, 1981.5       , 1981.58333333,
#        1981.66666667, 1981.75      , 1981.83333333, 1981.91666667,
#        1982.        , 1982.08333333, 1982.16666667, 1982.25      ,
#        1982.33333333, 1982.41666667, 1982.5       , 1982.58333333,
#        1982.66666667, 1982.75      , 1982.83333333, 1982.91666667,
#        1983.        , 1983.08333333, 1983.16666667, 1983.25      ,
#        1983.33333333, 1983.41666667, 1983.5       , 1983.58333333,
# ...

# %%
plt.plot(time, mei)
